# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from helpers import get_all_us_tickers, filter_daily_volume, drop_nan_days, get_data
import warnings

# %%
tickers = get_all_us_tickers()

# %%
# df = get_data(tickers, "2y", batch_size=500)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", module="yfinance")

# %%
df = get_data(tickers, start="2010-01-01", end="2026-03-03", batch_size=200)
# Out:
# Batch 0/37
# [*********************100%***********************]  200 of 200 completed
#
# 20 Failed downloads:
# ['AISPW', 'AERTW', 'ALFUW', 'ALDFW', 'ABLVW', 'ALCYW', 'ADSEW', 'AEAQW', 'AACBR', 'ACONW', 'AFRIW', 'ABVEW', 'AENTW', 'AIIOW', 'AIMDW', 'AFJKR', 'ADACW', 'AEVAW', 'ALISR', 'AIRJW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2010-01-01 -> 2026-03-03)')
# Batch 1/37
# [*********************100%***********************]  200 of 200 completed
#
# 20 Failed downloads:
# ['ATIIW', 'AUROW', 'ANNAW', 'ASPCR', 'APADR', 'AMPGR', 'ALVOW', 'ARTCW', 'ASBPW', 'APACR', 'APXTW', 'AREBW', 'ANSCW', 'AMPGZ', 'AMODW', 'ARBEW', 'ANGHW', 'ASPSW', 'ASPSZ', 'ASTLW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2010-01-01 -> 2026-03-03)')
# Batch 2/37
# [*********************100%***********************]  200 of 200 completed
#
# 28 Failed downloads:
# ...

# %%
df["High"]["AIHS"]
# Out:
# Date
# 2010-01-04      NaN
# 2010-01-05      NaN
# 2010-01-06      NaN
# 2010-01-07      NaN
# 2010-01-08      NaN
#               ...
# 2026-02-24    1.295
# 2026-02-25    1.364
# 2026-02-26    1.320
# 2026-02-27    1.301
# 2026-03-02    1.333
# Name: AIHS, Length: 4064, dtype: float64

# %%
df.loc[:, ~df.columns.duplicated()].to_parquet("AllUSData-20100101-20260303.parquet", engine="pyarrow")
